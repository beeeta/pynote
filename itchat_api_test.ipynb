# %%
# 测试itchat接口

import itchat

from itchat.content import *
# Out:
# █

# %%
itchat.auto_login()
# Out:
# Getting uuid of QR code.
# ...
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as 韓淘泥

# %%
dir(itchat)
# Out:
# ['Core',
#  'VERSION',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'add_friend',
#  'add_member_into_chatroom',
#  'auto_login',
#  'check_login',
#  'components',
#  'config',
#  'configured_reply',
#  'content',
#  'core',
#  'create_chatroom',
#  'delete_member_from_chatroom',
#  'dump_login_status',
#  'get_QR',
#  'get_QRuuid',
#  'get_chatrooms',
#  'get_contact',
#  'get_friends',
#  'get_head_img',
#  'get_mps',
#  'get_msg',
#  'instanceList',
#  'load_login_status',
#  'log',
#  'login',
#  'logout',
#  'msg_register',
#  'new_instance',
#  'originInstance',
#  'returnvalues',
#  'revoke',
#  'run',
#  'search_chatrooms',
#  'search_friends',
#  'search_mps',
#  'send',
#  'send_file',
#  'send_image',
#  'send_msg',
#  'send_raw_msg',
#  'send_video',
#  'set_alias',
#  'set_chatroom_name',
#  'set_logging',
#  'set_pinned',
#  'show_mobile_login',
# ...

# %%
itchat.get_friends()
# Out:
# <ContactList: [<User: {'MemberList': <ContactList: []>, 'UserName': '@ce522cc549f61a7af02fd71ac4db1d24', 'City': '', 'DisplayName': '', 'PYQuanPin': '', 'RemarkPYInitial': '', 'Province': '', 'KeyWord': '', 'RemarkName': '', 'PYInitial': '', 'EncryChatRoomId': '', 'Alias': '', 'Signature': '本来无一物', 'NickName': '韓淘泥', 'RemarkPYQuanPin': '', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=1594111250&username=@ce522cc549f61a7af02fd71ac4db1d24&skey=@crypt_a553e4dc_c3dac3ad6d96d01762fb9f47431b37cd', 'UniFriend': 0, 'Sex': 1, 'AppAccountFlag': 0, 'VerifyFlag': 0, 'ChatRoomId': 0, 'HideInputBarFlag': 0, 'AttrStatus': 0, 'SnsFlag': 177, 'MemberCount': 0, 'OwnerUin': 0, 'ContactFlag': 0, 'Uin': 2921491980, 'StarFriend': 0, 'Statues': 0, 'WebWxPluginSwitch': 0, 'HeadImgFlag': 1}>, <User: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@8933e84f10005b532fcf88bd7e86115064ea981da59e31aee661da38b60513fc', 'NickName': 'coolcat', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=669
# ...

# %%
itchat.send_msg('can you get it',toUserName='@8933e84f10005b532fcf88bd7e86115064ea981da59e31aee661da38b60513fc')
# Out:
# <ItchatReturnValue: {'BaseResponse': {'Ret': 0, 'ErrMsg': '请求成功', 'RawMsg': '请求成功'}, 'MsgID': '8861103507941831318', 'LocalID': '15345842927541'}>
# LOG OUT!

# %%
itchat.get_contact()
# Out:
# <ContactList: [<Chatroom: {'MemberList': <ContactList: [<ChatroomMember: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@ffb87b6adccd7bb532c5cf977b0f8a6aa2de71ba173fc4a8e4c10ece106fa46c', 'NickName': '彭燕《韩品汇贸易微小店》', 'AttrStatus': 103653, 'PYInitial': '', 'PYQuanPin': '', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'MemberStatus': 0, 'DisplayName': '3栋1201彭', 'KeyWord': ''}>, <ChatroomMember: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@c6f5cefc434affbd30d056fed7807776', 'NickName': '邓小云', 'AttrStatus': 2147582111, 'PYInitial': '', 'PYQuanPin': '', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'MemberStatus': 0, 'DisplayName': '6区3栋1901', 'KeyWord': 'zhu'}>, <ChatroomMember: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@c911620643eb1cb98a679148ff960bbb', 'NickName': 'vivian 👼 Wong', 'AttrStatus': 101024807, 'PYInitial': '', 'PYQuanPin': '', 'RemarkPYInitial': '', 'RemarkPYQuanPin': '', 'MemberStatus': 0, 'DisplayName': '6区5-1505黄', 'KeyWord': 'viv'
# ...
